# %%
# 1. 이메일 주소에서 아이디만 추출하는 코드를 작성하시오 hint(find, 슬라이싱)
email = "test123@gmail.com"
print(txt.find("@"))

idx = email.find("@")
email[:idx]
# Out:
# 7
# 'test123'

# %%
t ="I relly enjoy learning python programming because it is powerful and easy to use"
len(t.replace(" ", ""))
len(t.split())

'python' in t
'un' in t
# Out:
# False

# %%
#역순으로 할땐 앞의 숫자가 뒷숫자보다 커야함
#짝수는 두칸씩 뛰어넘는 개념? [::2]

# %%
data = [10, 20, 30, 40, 50]
# 1) 인덱스 2의값을 100으로 변경
data[2] = 100
print(data)
# 2) 인덱스 0부터 2까지를 [1, 2, 3]으로 변경
data[0:3] = [1, 2, 3]
print(data)
# Out:
# [10, 20, 100, 40, 50]
# [1, 2, 3, 40, 50]
